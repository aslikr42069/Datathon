# %%
import os
import pandas as pd

# %%
FLIGHTS_PATH = os.path.abspath('Flights_TEC_Valid.csv')
SALES_PATH = os.path.abspath('Sales_TEC_Valid.csv')

# %%
flights = pd.read_csv(FLIGHTS_PATH)
flights.head()
# Out:
#                           Flight_ID Aeronave DepartureStation ArrivalStation  \
# 0  ab954014077430bd842cfa305a55c0f8   XA-VBY               AT             AZ
# 1  efd86c996035dacdca7a0ccb2560dda1   XA-VIX               BM             AV
# 2  6cfa1bbaa44f08fc7d3061f034a6a5ce   XA-VBV               AW             AS
# 3  dd0fad3248951d2f71d63e6279aeaa4b   XA-VBW               AW             AS
# 4  d0987ee648eea254063bfe2b39571b67   XA-VAP               BA             AB
#
#       Destination_Type        Origin_Type                  STD  \
# 0    Ciudad Fronteriza   Ciudad Principal  2023-10-19 11:40:00
# 1  MX Amigos y Familia  Ciudad Fronteriza  2023-07-03 00:55:00
# 2  MX Amigos y Familia   Ciudad Principal  2024-02-16 17:10:00
# 3  MX Amigos y Familia   Ciudad Principal  2023-06-26 15:15:00
# 4                Playa   Ciudad Principal  2023-02-10 08:40:00
#
#                    STA  Capacity  Passengers  Bookings
# 0  2023-10-19 14:25:00       240       229.0     157.0
# ...

# %%
productos_excluir = [
    'Specials', 'COMBOS CREW', 'Vivabus', 'OFERTAS ', 'Transportaciones CUN',
    'VIVA PLAY', 'VivaTransfer', 'Hertz.', 'VIVA Taxis', 'Antros',
    'Transportaciones TLC', 'Transportaciones MTY', 'Alimentos Charter'
]

# %%
sales = pd.read_csv(SALES_PATH)
sales = sales[~sales['ProductType'].isin(productos_excluir)]
sales.head()
# Out:
#                           Flight_ID ProductType          ProductName  \
# 0  a05290288259526edd3601160b10e1de     Botanas  Carne Seca Habanero
# 1  08f6f97437df8db101b050f1110be656     Licores        Jw Red Label
# 2  4e09c949826a77207868412baeff6d30     Licores        Jack And Coke
# 3  c3e1568fe46c68d3174681d322d412b3     Licores         Jw Red Label
# 5  34ae909bf3699372fcd66f02af0bdd54     Licores          Ron Bacardi
#
#    Quantity  TotalSales
# 0         1        55.0
# 1         2       240.0
# 2         8       576.0
# 3         2       240.0
# 5         2       240.0

# %%
flightSales = sales.merge(flights, on='Flight_ID', how='outer')
flightSales.head()
# Out:
#                           Flight_ID ProductType          ProductName  \
# 0  a05290288259526edd3601160b10e1de     Botanas  Carne Seca Habanero
# 1  a05290288259526edd3601160b10e1de     Botanas              Cheetos
# 2  a05290288259526edd3601160b10e1de     Botanas        Ruffles Queso
# 3  a05290288259526edd3601160b10e1de   Refrescos      Coca Sin Azucar
# 4  a05290288259526edd3601160b10e1de     Licores        Jack And Coke
#
#    Quantity  TotalSales Aeronave DepartureStation ArrivalStation  \
# 0       1.0        55.0   XA-VIQ               AW             AO
# 1       2.0        98.0   XA-VIQ               AW             AO
# 2       6.0       294.0   XA-VIQ               AW             AO
# 3       2.0        96.0   XA-VIQ               AW             AO
# 4       1.0        72.0   XA-VIQ               AW             AO
#
#    Destination_Type       Origin_Type                  STD  \
# 0  Ciudad Principal  Ciudad Principal  2023-08-28 19:20:00
# ...

# %%
flightSales.to_csv('flight_sales.csv')
