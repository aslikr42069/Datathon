# %%
FLIGHT_SALES_PATH = '/home/chk/Documents/univ/maestria/dataton/Datathon/flight_sales.csv'

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dtype_options = {
    'Unnamed: 0': 'int64',
    'Flight_ID': 'str',
    'ProductType': 'str',
    'ProductName': 'str',
    'Quantity': 'float64',
    'TotalSales': 'float64',
    'Aeronave': 'str',
    'DepartureStation': 'str',
    'ArrivalStation': 'str',
    'DestinationType': 'str',
    'Origin_Type': 'str',
    'Capacity': 'float64',
    'Passengers': 'float64',
    'Bookings': 'float64'
}

parse_dates = ['STD', 'STA']

flightSales = pd.read_csv(FLIGHT_SALES_PATH, dtype=dtype_options, parse_dates=parse_dates)
flightSales.head()
# Out:
#    Unnamed: 0                         Flight_ID ProductType  \
# 0           0  a05290288259526edd3601160b10e1de     Botanas
# 1           1  a05290288259526edd3601160b10e1de     Botanas
# 2           2  a05290288259526edd3601160b10e1de     Botanas
# 3           3  a05290288259526edd3601160b10e1de   Refrescos
# 4           4  a05290288259526edd3601160b10e1de     Licores
#
#            ProductName  Quantity  TotalSales Aeronave DepartureStation  \
# 0  Carne Seca Habanero       1.0        55.0   XA-VIQ               AW
# 1              Cheetos       2.0        98.0   XA-VIQ               AW
# 2        Ruffles Queso       6.0       294.0   XA-VIQ               AW
# 3      Coca Sin Azucar       2.0        96.0   XA-VIQ               AW
# 4        Jack And Coke       1.0        72.0   XA-VIQ               AW
#
#   ArrivalStation  Destination_Type       Origin_Type                 STD  \
# 0             AO  Ciudad Principal  Ciudad Principal 2023-08-28 19:20:00
# 1             AO  Ciudad Principal  Ciudad Principal 2023-08-28 19:20:00
# 2             AO  Ciudad Principal  Ciudad Principal 2023-08-28 19:20:00
# 3             AO  Ciudad Principal  Ciudad Principal 2023-08-28 19:20:00
# 4             AO  Ciudad Principal  Ciudad Principal 2023-08-28 19:20:00
#
#                   STA  Capacity  Passengers  Bookings
# 0 2023-08-28 20:45:00     186.0       131.0     100.0
# 1 2023-08-28 20:45:00     186.0       131.0     100.0
# 2 2023-08-28 20:45:00     186.0       131.0     100.0
# 3 2023-08-28 20:45:00     186.0       131.0     100.0
# 4 2023-08-28 20:45:00     186.0       131.0     100.0

# %%
flightSales['STD'] = pd.to_datetime(flightSales['STD'])
flightSales['STA'] = pd.to_datetime(flightSales['STA'])
flightSales.head()
# Out:
#    Unnamed: 0                         Flight_ID ProductType  \
# 0           0  a05290288259526edd3601160b10e1de     Botanas
# 1           1  a05290288259526edd3601160b10e1de     Botanas
# 2           2  a05290288259526edd3601160b10e1de     Botanas
# 3           3  a05290288259526edd3601160b10e1de   Refrescos
# 4           4  a05290288259526edd3601160b10e1de     Licores
#
#            ProductName  Quantity  TotalSales Aeronave DepartureStation  \
# 0  Carne Seca Habanero       1.0        55.0   XA-VIQ               AW
# 1              Cheetos       2.0        98.0   XA-VIQ               AW
# 2        Ruffles Queso       6.0       294.0   XA-VIQ               AW
# 3      Coca Sin Azucar       2.0        96.0   XA-VIQ               AW
# 4        Jack And Coke       1.0        72.0   XA-VIQ               AW
#
#   ArrivalStation  Destination_Type       Origin_Type                 STD  \
# 0             AO  Ciudad Principal  Ciudad Principal 2023-08-28 19:20:00
# 1             AO  Ciudad Principal  Ciudad Principal 2023-08-28 19:20:00
# 2             AO  Ciudad Principal  Ciudad Principal 2023-08-28 19:20:00
# 3             AO  Ciudad Principal  Ciudad Principal 2023-08-28 19:20:00
# 4             AO  Ciudad Principal  Ciudad Principal 2023-08-28 19:20:00
#
#                   STA  Capacity  Passengers  Bookings
# 0 2023-08-28 20:45:00     186.0       131.0     100.0
# 1 2023-08-28 20:45:00     186.0       131.0     100.0
# 2 2023-08-28 20:45:00     186.0       131.0     100.0
# 3 2023-08-28 20:45:00     186.0       131.0     100.0
# 4 2023-08-28 20:45:00     186.0       131.0     100.0

# %%
flightSales.isnull().sum()
# Out:
# Unnamed: 0              0
# Flight_ID               0
# ProductType             0
# ProductName             0
# Quantity                0
# TotalSales              0
# Aeronave            59322
# DepartureStation    53494
# ArrivalStation      53494
# Destination_Type    53494
# Origin_Type         53494
# STD                 53494
# STA                 53494
# Capacity            53494
# Passengers          53523
# Bookings            53523
# dtype: int64

# %%
flightSales.duplicated().sum()
# Out:
# 0

# %%
flightSales.dtypes
# Out:
# Unnamed: 0                   int64
# Flight_ID                   object
# ProductType                 object
# ProductName                 object
# Quantity                   float64
# TotalSales                 float64
# Aeronave                    object
# DepartureStation            object
# ArrivalStation              object
# Destination_Type            object
# Origin_Type                 object
# STD                 datetime64[ns]
# STA                 datetime64[ns]
# Capacity                   float64
# Passengers                 float64
# Bookings                   float64
# dtype: object

# %%
flightSales['Flight_ID'].nunique()
# Out:
# 74482

# %%
flightSales['ProductName'].nunique()
# Out:
# 98

# %%
flightSales['ProductType'].unique()
# Out:
# array(['Botanas', 'Refrescos', 'Licores', 'Sopas', 'Galletas',
#        'Bebidas Calientes', 'Perecederos', 'Lacteos'], dtype=object)

# %%
flightSales[flightSales['ProductType'] == 'Lacteos']['ProductName'].drop_duplicates()
# Out:
# 141        Leche De Fresa Sc
# 301    Leche De Chocolate Sc
# Name: ProductName, dtype: object

# %%
flightSales[['ProductName', 'ProductType']].drop_duplicates()
# Out:
#                     ProductName ProductType
# 0           Carne Seca Habanero     Botanas
# 1                       Cheetos     Botanas
# 2                 Ruffles Queso     Botanas
# 3               Coca Sin Azucar   Refrescos
# 4                 Jack And Coke     Licores
# ...                         ...         ...
# 250483       Kacang Flaming Hot     Botanas
# 255826            Licor Charter     Licores
# 297808       Quaker Avena Moras    Galletas
# 320012   Quaker Natural Balance    Galletas
# 379493  Nissin Limon Y Habanero       Sopas
#
# [98 rows x 2 columns]

# %%
flightSales['STD'].min()
# Out:
# Timestamp('2023-01-02 00:20:00')

# %%
flightSales['STD'].max()
# Out:
# Timestamp('2024-01-01 13:20:00')

# %%
flightSales['month'] = flightSales['STD'].dt.to_period('M')
monthFlightSales = flightSales.groupby(['ProductType', 'month']).sum(numeric_only=True)
monthFlightSales.reset_index(inplace=True)
monthFlightSales.head(20)
# Out:
#           ProductType    month   Unnamed: 0  Quantity  TotalSales    Capacity  \
# 0   Bebidas Calientes  2023-01   6407478308   10752.0    430080.0   1504420.0
# 1   Bebidas Calientes  2023-02   5606859196   10060.0    402400.0   1335036.0
# 2   Bebidas Calientes  2023-03   6828354628   12449.0    497954.0   1640054.0
# 3   Bebidas Calientes  2023-04   7194551541   12613.0    504514.0   1637276.0
# 4   Bebidas Calientes  2023-05   7111214829   12849.0    513960.0   1629542.0
# 5   Bebidas Calientes  2023-06   7720078437   13903.0    556120.0   1758110.0
# 6   Bebidas Calientes  2023-07   8821483629   16302.0    652080.0   1979686.0
# 7   Bebidas Calientes  2023-08   7757009687   15611.0    697862.0   1947696.0
# 8   Bebidas Calientes  2023-09   6683670634   14349.0    645633.0   1781410.0
# 9   Bebidas Calientes  2023-10   6846481613   14451.0    650242.0   1802086.0
# 10  Bebidas Calientes  2023-11   6548099938   13794.0    620714.0   1764686.0
# 11  Bebidas Calientes  2023-12   6840255121   13483.0    606719.0   1799712.0
# 12            Botanas  2023-01  30612107637   85546.0   3969048.0   6881168.0
# 13            Botanas  2023-02  28601042428   74367.0   3467002.0   6577690.0
# 14            Botanas  2023-03  35850002966   97689.0   4552332.0   8265522.0
# 15            Botanas  2023-04  40087101096  112737.0   5245835.0   8932288.0
# 16            Botanas  2023-05  38011760499  104878.0   4886614.0   8559588.0
# 17            Botanas  2023-06  40153423877  118641.0   5437811.0   9032036.0
# 18            Botanas  2023-07  45847739867  149730.0   6889642.0  10153780.0
# 19            Botanas  2023-08  42043909642  139786.0   6927334.0  10546758.0
#
#     Passengers   Bookings
# 0    1305802.0   789974.0
# 1    1164560.0   730068.0
# 2    1469811.0   913587.0
# 3    1486826.0   863627.0
# 4    1476188.0   904409.0
# 5    1584538.0   941748.0
# 6    1838895.0  1012013.0
# 7    1763230.0   987905.0
# 8    1577159.0   974752.0
# 9    1649750.0   999875.0
# 10   1581957.0   970969.0
# 11   1578779.0   942056.0
# 12   5940044.0  3600149.0
# 13   5709197.0  3578405.0
# 14   7378682.0  4562947.0
# 15   8108221.0  4684958.0
# 16   7804051.0  4742107.0
# 17   8182304.0  4834816.0
# 18   9449298.0  5145474.0
# 19   9579056.0  5308181.0

# %%
monthFlightSales.columns
# Out:
# Index(['ProductType', 'month', 'Unnamed: 0', 'Quantity', 'TotalSales',
#        'Capacity', 'Passengers', 'Bookings'],
#       dtype='object')

# %%
fig, ax = plt.subplots(figsize=(10, 6))

for product_type in monthFlightSales['ProductType'].unique():
    type_df = monthFlightSales[monthFlightSales['ProductType'] == product_type]
    ax.plot(type_df['month'].astype(str), type_df['TotalSales'], label=product_type)

ax.set_title('Total de ventas por mes')
ax.set_xlabel('Mes')
ax.set_ylabel('Total de ventas')
ax.legend()
ax.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
